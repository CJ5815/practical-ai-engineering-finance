# %% [markdown]
# # Week 1: Your First Jupyter Notebook
#
# This notebook is a quick preview of what you'll use starting in Week 2 for data exploration. Unlike a `.py` script, a notebook runs one **cell** at a time and shows each cell's output immediately below it — code cells and markdown cells (like this one) can be mixed freely.

# %%
import pandas as pd

prices = pd.read_csv("../data/sample/prices.csv")
prices.head()

# %% [markdown]
# ## Calculate a Simple Return
#
# `ai_finance_course.returns` already has a `simple_return` helper. Reuse it instead of writing the formula again.

# %%
from ai_finance_course.returns import simple_return

beginning_price = prices["close"].iloc[0]
ending_price = prices["close"].iloc[-1]

simple_return(beginning_price, ending_price)

# %% [markdown]
# ## Try It Yourself
#
# Change the row positions below to compare the return over a shorter window, then re-run the cell (`Shift+Enter`).

# %%
# Return over the first five rows only
simple_return(prices["close"].iloc[0], prices["close"].iloc[4])
